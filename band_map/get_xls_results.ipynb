# %% [markdown]
# 本脚本用于HDCNN进行对比实验

# %%
###################################
#count results
data_name = "PaviaU"
from main import RET
results =[]
for i in range(5):
    # !python get_prefile_ss.py --data_name "PaviaU" --pt 0.015 --pv 0.06
    model = RET(data_name,100)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_SVM_"+avg[0]+'.xls')

# #count results
# data_name = "PaviaU"
# from main import RET
# results =[]
# for i in range(5):
#     !python get_prefile_ss.py --data_name "PaviaU" --pt 0.025 --pv 0.06
#     model = RET(data_name,100)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')

# #count results
# data_name = "PaviaU"
# from main import RET
# results =[]
# for i in range(5):
#     !python get_prefile_ss.py --data_name "PaviaU" --pt 0.028 --pv 0.06
#     model = RET(data_name,100)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')

# #count results
# data_name = "PaviaU"
# from main import RET
# results =[]
# for i in range(5):
#     !python get_prefile_ss.py --data_name "PaviaU" --pt 0.032 --pv 0.06
#     model = RET(data_name,100)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')

# #count results
# data_name = "PaviaU"
# from main import RET
# results =[]
# for i in range(5):
#     !python get_prefile_ss.py --data_name "PaviaU" --pt 0.034 --pv 0.06
#     model = RET(data_name,100)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')

# #count results
# data_name = "PaviaU"
# from main import RET
# results =[]
# for i in range(5):
#     !python get_prefile_ss.py --data_name "PaviaU" --pt 0.031 --pv 0.06
#     model = RET(data_name,100)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')
# Out:
# 164624
# 1646
# Finished!
# training accuary: 1.0
# test accuary: 0.8933228871815608
# 164624
# 1646
# Finished!
# training accuary: 0.971875
# test accuary: 0.8892539425798626
# 164624
# 1646
# Finished!
# training accuary: 0.946875
# test accuary: 0.897745653052972
# 164624
# 1646
# Finished!
# training accuary: 0.975
# test accuary: 0.9033309745248685
# 164624
# 1646
# Finished!
# training accuary: 0.990625
# test accuary: 0.8992873028710069

# %%
###################################
#count results
data_name = "Indian_pines"
from main import RET
results =[]
for i in range(5):
    # !python get_prefile_ss.py --data_name "Indian_pines" --pt 0.07 --pv 0.10
    model = RET(data_name,100)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_SVM_"+avg[0]+'.xls')



###################################
#count results
data_name = "Indian_pines"
from main import RET
results =[]
for i in range(5):
    # !python get_prefile_ss.py --data_name "Indian_pines" --pt 0.06 --pv 0.10
    model = RET(data_name,100)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_SVM_"+avg[0]+'.xls')


# ###################################
# #count results
# data_name = "Indian_pines"
# from main import RET
# results =[]
# for i in range(5):
#     !python get_prefile_ss.py --data_name "Indian_pines" --pt 0.035 --pv 0.10
#     model = RET(data_name,100)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')

# ###################################
# #count results
# data_name = "Indian_pines"
# from main import RET
# results =[]
# for i in range(5):
#     !python get_prefile_ss.py --data_name "Indian_pines" --pt 0.042 --pv 0.10
#     model = RET(data_name,100)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')

# ###################################
# #count results
# data_name = "Indian_pines"
# from main import RET
# results =[]
# for i in range(5):
#     !python get_prefile_ss.py --data_name "Indian_pines" --pt 0.060 --pv 0.10
#     model = RET(data_name,100)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')

# ###################################
# #count results
# data_name = "Indian_pines"
# from main import RET
# results =[]
# for i in range(5):
#     !python get_prefile_ss.py --data_name "Indian_pines" --pt 0.065 --pv 0.10
#     model = RET(data_name,100)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')
# Out:
# 10776
# 108
# Finished!
# training accuary: 0.990234375
# test accuary: 0.7752009184845006
# 10776
# 108
# Finished!
# training accuary: 0.978515625
# test accuary: 0.7714121699196326
# 10776
# 108
# Finished!
# training accuary: 0.9765625
# test accuary: 0.7694603903559127
# 10776
# 108
# Finished!
# training accuary: 0.986328125
# test accuary: 0.779219288174512
# 10776
# 108
# Finished!
# training accuary: 0.994140625
# test accuary: 0.7738231917336394
# 10776
# 108
# Finished!
# training accuary: 0.9828850855745721
# test accuary: 0.7561833446789199
# 10776
# 108
# Finished!
# training accuary: 1.0
# test accuary: 0.765600181529385
# 10776
# 108
# Finished!
# training accuary: 0.9828850855745721
# test accuary: 0.7581120943952803
# 10776
# 108
# Finished!
# training accuary: 0.9951100244498777
# test accuary: 0.7582255502609485
# 10776
# 108
# Finished!
# training accuary: 0.9853300733496333
# test accuary: 0.7421148173360562
# 10776
# 108
# Finished!
# training accuary: 0.9861111111111112
# test accuary: 0.748307761732852
# 10776
# 108
# Finished!
# training accuary: 1.0
# test accuary: 0.7290162454873647
# 10776
# 108
# Finished!
# training accuary: 1.0
# test accuary: 0.7372518050541517
# 10776
# 108
# Finished!
# training accuary: 0.9777777777777777
# test accuary: 0.7375902527075813
# 10776
# 108
# Finished!
# training accuary: 1.0
# test accuary: 0.7395081227436823
# 10776
# 108
# Finished!
# training accuary: 1.0
# test accuary: 0.7790922534410192
# 10776
# 108
# Finished!
# training accuary: 0.9837587006960556
# test accuary: 0.7539529063815266
# 10776
# 108
# Finished!
# training accuary: 1.0
# test accuary: 0.7803435331589125
# 10776
# 108
# Finished!
# training accuary: 1.0
# test accuary: 0.7638493914230463
# 10776
# 108
# Finished!
# training accuary: 0.9791183294663574
# test accuary: 0.7429188943237401
# 10776
# 108
# Finished!
# training accuary: 1.0
# test accuary: 0.7995354239256678
# 10776
# 108
# Finished!
# training accuary: 1.0
# test accuary: 0.7839721254355401
# 10776
# 108
# Finished!
# training accuary: 0.9788961038961039
# test accuary: 0.786411149825784
# 10776
# 108
# Finished!
# training accuary: 0.9788961038961039
# test accuary: 0.7883855981416957
# 10776
# 108
# Finished!
# training accuary: 0.9918831168831169
# test accuary: 0.7835075493612079
# 10776
# 108
# Finished!
# training accuary: 0.9984962406015038
# test accuary: 0.800981652448288
# 10776
# 108
# Finished!
# training accuary: 0.9954887218045113
# test accuary: 0.8046044174360173
# 10776
# 108
# Finished!
# training accuary: 0.9789473684210527
# test accuary: 0.798878111487671
# 10776
# 108
# Finished!
# training accuary: 0.9819548872180451
# test accuary: 0.7971251606871567
# 10776
# 108
# Finished!
# training accuary: 0.9864661654135338
# test accuary: 0.7947878929531378

# %%
###################################
#count results
data_name = "Houston"
from main import RET
results =[]
for i in range(5):
    # !python get_prefile_ss.py --data_name "Houston" --pt 0.06 --pv 0.10
    model = RET(data_name,100)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_SVM_"+avg[0]+'.xls')



###################################
#count results
data_name = "Houston"
from main import RET
results =[]
for i in range(5):
    # !python get_prefile_ss.py --data_name "Houston" --pt 0.07 --pv 0.10
    model = RET(data_name,100)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
# book.save(data_name+"_SVM_"+avg[0]+'.xls')


###################################
#count results
data_name = "Houston"
from main import RET
results =[]
for i in range(5):
    # !python get_prefile_ss.py --data_name "Houston" --pt 0.052 --pv 0.10
    model = RET(data_name,100)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_SVM_"+avg[0]+'.xls')

###################################
#count results
data_name = "Houston"
from main import RET
results =[]
for i in range(5):
    # !python get_prefile_ss.py --data_name "Houston" --pt 0.045 --pv 0.10
    model = RET(data_name,100)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_SVM_"+avg[0]+'.xls')

###################################
#count results
data_name = "Houston"
from main import RET
results =[]
for i in range(5):
    # !python get_prefile_ss.py --data_name "Houston" --pt 0.056 --pv 0.10
    model = RET(data_name,100)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_SVM_"+avg[0]+'.xls')

###################################
#count results
data_name = "Houston"
from main import RET
results =[]
for i in range(5):
    # !python get_prefile_ss.py --data_name "Houston" --pt 0.040 --pv 0.10
    model = RET(data_name,100)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_SVM_"+avg[0]+'.xls')
