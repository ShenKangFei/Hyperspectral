# %% [markdown]
# 本脚本用于HDCNN进行对比实验

# %%
#count results
data_name = "Houston"

# %%
###################################
from main import RET
results =[]
for i in range(1):
    # !python get_prefile.py --data_name "Houston" -- rate 0.025
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"TWCNN"+avg[0]+'.xls')


###################################
from main import RET
results =[]
for i in range(1):
    # !python get_prefile.py --data_name "Houston" -- rate 0.05
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"TWCNN"+avg[0]+'.xls')


###################################
from main import RET
results =[]
for i in range(1):
    # !python get_prefile.py --data_name "Houston" -- rate 0.06
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"TWCNN"+avg[0]+'.xls')
# Out:
# WARNING:tensorflow:From G:\lidi\程序\RLBS对比算法\波段选择程序 - TNN - 大图\main.py:41: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# (1905, 349, 144)
# (1905, 349, 144)
# X_train shape: (751, 15, 15, 144)
# X_test shape: (14278, 15, 15, 144)
# 751 train samples
# 14278 test samples
# (1905, 349, 144)
# WARNING:tensorflow:From G:\lidi\程序\RLBS对比算法\波段选择程序 - TNN - 大图\main.py