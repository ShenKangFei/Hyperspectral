# %% [markdown]
# 本脚本用于HDCNN进行对比实验

# %%
#count results
data_name = "Houston"

# %%
###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "Houston" -- rate 0.05
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"TWCNN"+avg[0]+'.xls')
# Out:
# cuda:0
# C:\ProgramData\Anaconda3\lib\site-packages\torch\cuda\nccl.py:24: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn('PyTorch is not compiled with NCCL support')
# Finished Training
# OA: 0.8738  | AA:  0.8610  | Kappa:  0.8634  | Time: -1579181474.7s
# cuda:0
# Finished Training
# OA: 0.8569  | AA:  0.8548  | Kappa:  0.8452  | Time: -1579181485.2s
# cuda:0
# Finished Training
# OA: 0.8777  | AA:  0.8688  | Kappa:  0.8677  | Time: -1579181484.5s
# cuda:0
# Finished Training
# OA: 0.8818  | AA:  0.8797  | Kappa:  0.8721  | Time: -1579181486.8s
# cuda:0
# Finished Training
# OA: 0.8594  | AA:  0.8570  | Kappa:  0.8479  | Time: -1579181484.7s
# cuda:0
# Finished Training
# OA: 0.8603  | AA:  0.8558  | Kappa:  0.8489  | Time: -1579181487.1s
# cuda:0
# Finished Training
# OA: 0.8558  | AA:  0.8469  | Kappa:  0.8439  | Time: -1579181484.5s
# cuda:0
# Finished Training
# OA: 0.8629  | AA:  0.8529  | Kappa:  0.8516  | Time: -1579181486.9s
# cuda:0
# Finished Training
# OA: 0.8580  | AA:  0.8516  | Kappa:  0.8464  | Time: -1579181484.0s
# cuda:0
# Finished Training
# OA: 0.8662  | AA:  0.8634  | Kappa:  0.8553  | Time: -1579181485.4s
# cuda:0
# Finished Training
# OA: 0.8734  | AA:  0.8606  | Kappa:  0.8630  | Time: -1579181484.4s
# cuda:0
# Finished Training
# OA: 0.8625  | AA:  0.8615  | Kappa:  0.8513  | Time: -1579181484.9s
# cuda:0
# Finished Training
# OA: 0.8646  | AA:  0.8593  | Kappa:  0.8535  | Time: -1579181484.5s
# cuda:0
# Finished Training
# OA: 0.8638  | AA:  0.8621  | Kappa:  0.8527  | Time: -1579181484.2s
# cuda:0
# Finished Training
# OA: 0.8386  | AA:  0.8456  | Kappa:  0.8256  | Time: -1579181485.2s
# cuda:0
# Finished Training
# OA: 0.8603  | AA:  0.8510  | Kappa:  0.8489  | Time: -1579181488.3s
# cuda:0
# Finished Training
# OA: 0.8825  | AA:  0.8787  | Kappa:  0.8729  | Time: -1579181493.0s
# cuda:0
# Finished Training
# OA: 0.8117  | AA:  0.8128  | Kappa:  0.7963  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8520  | AA:  0.8446  | Kappa:  0.8400  | Time: -1579181492.0s
# cuda:0
# Finished Training
# OA: 0.8648  | AA:  0.8616  | Kappa:  0.8537  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8362  | AA:  0.8301  | Kappa:  0.8227  | Time: -1579181490.9s
# cuda:0
# Finished Training
# OA: 0.8200  | AA:  0.8190  | Kappa:  0.8053  | Time: -1579181492.4s
# cuda:0
# Finished Training
# OA: 0.8648  | AA:  0.8583  | Kappa:  0.8538  | Time: -1579181490.8s
# cuda:0
# Finished Training
# OA: 0.8735  | AA:  0.8713  | Kappa:  0.8632  | Time: -1579181492.2s
# cuda:0
# Finished Training
# OA: 0.8691  | AA:  0.8582  | Kappa:  0.8583  | Time: -1579181490.9s
# cuda:0
# Finished Training
# OA: 0.8534  | AA:  0.8501  | Kappa:  0.8415  | Time: -1579181490.7s
# cuda:0
# Finished Training
# OA: 0.8736  | AA:  0.8670  | Kappa:  0.8633  | Time: -1579181492.3s
# cuda:0
# Finished Training
# OA: 0.8894  | AA:  0.8847  | Kappa:  0.8804  | Time: -1579181490.7s
# cuda:0
# Finished Training
# OA: 0.8750  | AA:  0.8679  | Kappa:  0.8648  | Time: -1579181493.0s
# cuda:0
# Finished Training
# OA: 0.8665  | AA:  0.8627  | Kappa:  0.8557  | Time: -1579181490.7s
# cuda:0
# Finished Training
# OA: 0.8628  | AA:  0.8573  | Kappa:  0.8516  | Time: -1579181491.8s
# cuda:0
# Finished Training
# OA: 0.8794  | AA:  0.8689  | Kappa:  0.8695  | Time: -1579181491.1s
# cuda:0
# Finished Training
# OA: 0.8713  | AA:  0.8714  | Kappa:  0.8608  | Time: -1579181491.3s
# cuda:0
# Finished Training
# OA: 0.8735  | AA:  0.8598  | Kappa:  0.8632  | Time: -1579181491.5s
# cuda:0
# Finished Training
# OA: 0.8811  | AA:  0.8729  | Kappa:  0.8714  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8791  | AA:  0.8728  | Kappa:  0.8692  | Time: -1579181493.1s
# cuda:0
# Finished Training
# OA: 0.8666  | AA:  0.8604  | Kappa:  0.8557  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8640  | AA:  0.8573  | Kappa:  0.8528  | Time: -1579181491.4s
# cuda:0
# Finished Training
# OA: 0.8744  | AA:  0.8664  | Kappa:  0.8641  | Time: -1579181491.3s
# cuda:0
# Finished Training
# OA: 0.8804  | AA:  0.8697  | Kappa:  0.8707  | Time: -1579181491.3s
# cuda:0
# Finished Training
# OA: 0.8870  | AA:  0.8808  | Kappa:  0.8777  | Time: -1579181493.1s
# cuda:0
# Finished Training
# OA: 0.8807  | AA:  0.8786  | Kappa:  0.8709  | Time: -1579181491.3s
# cuda:0
# Finished Training
# OA: 0.8621  | AA:  0.8504  | Kappa:  0.8508  | Time: -1579181492.0s
# cuda:0
# Finished Training
# OA: 0.8590  | AA:  0.8492  | Kappa:  0.8474  | Time: -1579181491.1s
# cuda:0
# Finished Training
# OA: 0.8629  | AA:  0.8570  | Kappa:  0.8517  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8684  | AA:  0.8659  | Kappa:  0.8576  | Time: -1579181492.9s
# cuda:0
# Finished Training
# OA: 0.8705  | AA:  0.8615  | Kappa:  0.8599  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8587  | AA:  0.8508  | Kappa:  0.8471  | Time: -1579181492.7s
# cuda:0
# Finished Training
# OA: 0.8783  | AA:  0.8691  | Kappa:  0.8683  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8592  | AA:  0.8498  | Kappa:  0.8476  | Time: -1579181491.3s
# cuda:0
# Finished Training
# OA: 0.8253  | AA:  0.8242  | Kappa:  0.8109  | Time: -1579181492.6s
# cuda:0
# Finished Training
# OA: 0.8674  | AA:  0.8618  | Kappa:  0.8566  | Time: -1579181491.3s
# cuda:0
# Finished Training
# OA: 0.8585  | AA:  0.8451  | Kappa:  0.8468  | Time: -1579181493.0s
# cuda:0
# Finished Training
# OA: 0.8810  | AA:  0.8666  | Kappa:  0.8712  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8832  | AA:  0.8710  | Kappa:  0.8737  | Time: -1579181491.1s
# cuda:0
# Finished Training
# OA: 0.8669  | AA:  0.8620  | Kappa:  0.8560  | Time: -1579181492.0s
# cuda:0
# Finished Training
# OA: 0.8701  | AA:  0.8579  | Kappa:  0.8595  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8594  | AA:  0.8597  | Kappa:  0.8479  | Time: -1579181493.2s
# cuda:0
# Finished Training
# OA: 0.8814  | AA:  0.8669  | Kappa:  0.8716  | Time: -1579181491.3s
# cuda:0
# Finished Training
# OA: 0.8587  | AA:  0.8528  | Kappa:  0.8472  | Time: -1579181492.1s
# cuda:0
# Finished Training
# OA: 0.8847  | AA:  0.8722  | Kappa:  0.8753  | Time: -1579181491.3s
# cuda:0
# Finished Training
# OA: 0.8823  | AA:  0.8797  | Kappa:  0.8727  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8775  | AA:  0.8689  | Kappa:  0.8674  | Time: -1579181491.4s
# cuda:0
# Finished Training
# OA: 0.8850  | AA:  0.8720  | Kappa:  0.8755  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8828  | AA:  0.8808  | Kappa:  0.8732  | Time: -1579181493.3s
# cuda:0
# Finished Training
# OA: 0.8898  | AA:  0.8843  | Kappa:  0.8808  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8652  | AA:  0.8659  | Kappa:  0.8543  | Time: -1579181491.6s
# cuda:0
# Finished Training
# OA: 0.8720  | AA:  0.8680  | Kappa:  0.8615  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8629  | AA:  0.8612  | Kappa:  0.8517  | Time: -1579181491.2s
# cuda:0
# Finished Training
# OA: 0.8819  | AA:  0.8722  | Kappa:  0.8723  | Time: -1579181493.2s
# cuda:0
# Finished Training
# OA: 0.8604  | AA:  0.8574  | Kappa:  0.8490  | Time: -1579181491.3s
# cuda:0
# Finished Training
# OA: 0.8741  | AA:  0.8704  | Kappa:  0.8638  | Time: -1579181492.1s
# cuda:0
# Finished Training
# OA: 0.8481  | AA:  0.8442  | Kappa:  0.8356  | Time: -1579181491.0s
# cuda:0
# Finished Training
# OA: 0.8636  | AA:  0.8556  | Kappa:  0.8524  | Time: -1579181491.1s
# cuda:0
# Finished Training
# OA: 0.8643  | AA:  0.8577  | Kappa:  0.8531  | Time: -1579181492.7s
