# %% [markdown]
# 本脚本用于HDCNN进行对比实验

# %%
#count results
data_name = "PaviaU"

# %%
###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.03
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.03
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.03
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.032
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.031
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.029
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.028
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.027
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.033
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.03
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.03
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.03
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.035
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.036
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')

###################################
from main import RET
results =[]
for i in range(5):
    # !python get_prefile.py --data_name "PaviaU" -- rate 0.03
    model = RET(data_name)
    results.append(model.results)
import numpy as np
results = np.array(results)
avarage = results.mean(axis=0)*100
std = results.std(axis=0)*100
avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
import xlwt
import time
#创建一个Workbook对象，相当于创建了一个Excel文件
book=xlwt.Workbook(encoding="utf-8",style_compression=0)
sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
clo_0 = ["OA","AA","Kappa"]+list(range(16))
row_o = [data_name]+list(range(5))+["avg"]
for i in range(len(row_o)):
    sheet.write(0, i,row_o[i])
for j in range(len(clo_0)):
    sheet.write(j+1, 0,clo_0[j])
for i in range(len(results)):
    for j in range(len(results[0])):
        sheet.write(j+1, i+1,results[i][j])
for j in range(len(results[0])):
    sheet.write(j+1,6,avg[j])
book.save(data_name+"_NAIVE_ANN_"+avg[0]+'.xls')
# Out:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py", line 39, in _open_file
#     return open(file_like, mode), True
# FileNotFoundError: [Errno 2] No such file or directory: 'g:\\lidi\\程序\\RLBS对比算法\\波段选择程序 - TNN - 副本 (2)/data/PaviaU/PaviaU.mat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "get_prefile.py", line 101, in <module>
#     data_ori, labels_ori = readData(data_name)
#   File "get_prefile.py", line 31, in readData
#     data = sio.loadmat(path+'/PaviaU.mat')['paviaU']
#   File "C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py", line 216, in loadmat
#     with _open_file_context(file_name, appendmat) as f:
#   File "C:\ProgramData\Anaconda3\lib\contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py", line 19, in _open_file_context
#     f, opened = _open_file(file_like, appendmat, mode)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py", line 45, in _open_file
#     return open(file_like, mode), True
# FileNotFoundError: [Errno 2] No such file or directory: 'g:\\lidi\\程序\\RLBS对比算法\\波段选择程序 - TNN - 副本 (2)/data/PaviaU/PaviaU.mat'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in _open_file(file_like, appendmat, mode)
#      38     try:
# ---> 39         return open(file_like, mode), True
#      40     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'g:\\lidi\\程序\\RLBS对比算法\\波段选择程序 - TNN - 副本 (2)/data/PaviaU/PaviaU_pre.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e6cdee51d3b1> in <module>
#       4 for i in range(5):
#       5     get_ipython().system('python get_prefile.py --data_name "PaviaU" -- rate 0.03')
# ----> 6     model = RET(data_name)
#       7     results.append(model.results)
#       8 import numpy as np
#
# g:\lidi\程序\RLBS对比算法\波段选择程序 - TNN - 副本 (2)\main.py in __init__(self, data_name, num_band_seclection)
#      27     def __init__(self,data_name = "Indian_pines",num_band_seclection = 60 ):
#      28         self.data_name = data_name
# ---> 29         data_norm,labels_ori,x_train,y_train,train_loc,x_test,y_test,test_loc=load_data(self.data_name)
#      30         nrows = data_norm.shape[0]
#      31         ncols = data_norm.shape[1]
#
# g:\lidi\程序\RLBS对比算法\波段选择程序 - TNN - 副本 (2)\processing_library.py in load_data(data_name)
#      19     '''读取数据'''
#      20     path = os.getcwd()
# ---> 21     pre = sio.loadmat(path + '/data/' + data_name + '/' + data_name + '_pre.mat')
#      22
#      23     data_norm = pre['data_norm']
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     214     """
#     215     variable_names = kwargs.pop('variable_names', None)
# --> 216     with _open_file_context(file_name, appendmat) as f:
#     217         MR, _ = mat_reader_factory(f, **kwargs)
#     218         matfile_dict = MR.get_variables(variable_names)
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in _open_file_context(file_like, appendmat, mode)
#      17 @contextmanager
#      18 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 19     f, opened = _open_file(file_like, appendmat, mode)
#      20     yield f
#      21     if opened:
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in _open_file(file_like, appendmat, mode)
#      43             if appendmat and not file_like.endswith('.mat'):
#      44                 file_like += '.mat'
# ---> 45             return open(file_like, mode), True
#      46         else:
#      47             raise IOError('Reader needs file name or open file-like object')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'g:\\lidi\\程序\\RLBS对比算法\\波段选择程序 - TNN - 副本 (2)/data/PaviaU/PaviaU_pre.mat'
